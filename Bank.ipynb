# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

# %%
from pandas import DataFrame

# %% [markdown]
# creating dataframe object

# %%
bank=pd.read_csv('/content/gdrive/MyDrive/principles of data science lab/bank_marketing_test.csv')
bank
# Out:
#       age          job  marital          education  default housing loan  \
# 0      56     services  married        high.school       no      no  yes
# 1      41  blue-collar  married            unknown  unknown      no   no
# 2      25     services   single        high.school       no     yes   no
# 3      35  blue-collar  married           basic.6y       no     yes   no
# 4      46  blue-collar  married           basic.6y  unknown     yes  yes
# ...   ...          ...      ...                ...      ...     ...  ...
# 8232   41  blue-collar  married           basic.9y       no     yes   no
# 8233   60  blue-collar  married           basic.4y       no     yes   no
# 8234   32       admin.  married  university.degree       no      no   no
# 8235   32       admin.  married  university.degree       no     yes   no
# 8236   36       admin.  married  university.degree       no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
bank.head(5)
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   56     services  married  high.school       no      no  yes  telephone
# 1   41  blue-collar  married      unknown  unknown      no   no  telephone
# 2   25     services   single  high.school       no     yes   no  telephone
# 3   35  blue-collar  married     basic.6y       no     yes   no  telephone
# 4   46  blue-collar  married     basic.6y  unknown     yes  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# confirming data frame

# %%
bank.shape
# Out:
# (8237, 21)

# %%
bank.describe()
# Out:
#                age     duration    campaign        pdays     previous  \
# count  8237.000000  8237.000000  8237.00000  8237.000000  8237.000000
# mean     40.116547   256.007648     2.60471   962.228724     0.174335
# std      10.465328   259.728737     2.91562   187.533881     0.500565
# min      17.000000     4.000000     1.00000     0.000000     0.000000
# 25%      32.000000   101.000000     1.00000   999.000000     0.000000
# 50%      38.000000   179.000000     2.00000   999.000000     0.000000
# 75%      47.000000   316.000000     3.00000   999.000000     0.000000
# max      89.000000  4918.000000    43.00000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   8237.000000     8237.000000    8237.000000  8237.000000  8237.000000
# mean       0.070147       93.577806     -40.545320     3.608206  5166.589790
# std        1.574685        0.582138       4.623626     1.735931    72.470977
# ...

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8237 entries, 0 to 8236
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8237 non-null   int64
#  1   job             8237 non-null   object
#  2   marital         8237 non-null   object
#  3   education       8237 non-null   object
#  4   default         8237 non-null   object
#  5   housing         8237 non-null   object
#  6   loan            8237 non-null   object
#  7   contact         8237 non-null   object
#  8   month           8237 non-null   object
#  9   day_of_week     8237 non-null   object
#  10  duration        8237 non-null   int64
#  11  campaign        8237 non-null   int64
#  12  pdays           8237 non-null   int64
#  13  previous        8237 non-null   int64
#  14  poutcome        8237 non-null   object
#  15  emp.var.rate    8237 non-null   float64
#  16  cons.price.idx  8237 non-null   float64
# ...

# %% [markdown]
# converting string to categories

# %%
bank['marital'].astype('category')
# Out:
# 0       married
# 1       married
# 2        single
# 3       married
# 4       married
#          ...
# 8232    married
# 8233    married
# 8234    married
# 8235    married
# 8236    married
# Name: marital, Length: 8237, dtype: category
# Categories (4, object): ['divorced', 'married', 'single', 'unknown']

# %%
bank['marital']=bank['marital'].astype('category')

# %%
bank['contact']=bank['contact'].astype('category')

# %%
bank.describe(include='category')
# Out:
#         marital   contact
# count      8237      8237
# unique        4         2
# top     married  cellular
# freq       5041      5215

# %% [markdown]
# type conversion using programming constructs

# %%
for col in['marital','contact']:
  bank[col]=bank[col].astype('category')
  bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8237 entries, 0 to 8236
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             8237 non-null   int64
#  1   job             8237 non-null   object
#  2   marital         8237 non-null   category
#  3   education       8237 non-null   object
#  4   default         8237 non-null   object
#  5   housing         8237 non-null   object
#  6   loan            8237 non-null   object
#  7   contact         8237 non-null   category
#  8   month           8237 non-null   object
#  9   day_of_week     8237 non-null   object
#  10  duration        8237 non-null   int64
#  11  campaign        8237 non-null   int64
#  12  pdays           8237 non-null   int64
#  13  previous        8237 non-null   int64
#  14  poutcome        8237 non-null   object
#  15  emp.var.rate    8237 non-null   float64
#  16  cons.price.idx  8237 non-null   float64
# ...

# %% [markdown]
# basic visualization

# %%
bank['duration'].mean()
# Out:
# 256.0076484156853

# %%
dur=bank['duration']

# %%
dur.min(),dur.mean(),dur.median(),dur.max()
# Out:
# (4, 256.0076484156853, 179.0, 4918)

# %%
bank.describe()
# Out:
#                age     duration    campaign        pdays     previous  \
# count  8237.000000  8237.000000  8237.00000  8237.000000  8237.000000
# mean     40.116547   256.007648     2.60471   962.228724     0.174335
# std      10.465328   259.728737     2.91562   187.533881     0.500565
# min      17.000000     4.000000     1.00000     0.000000     0.000000
# 25%      32.000000   101.000000     1.00000   999.000000     0.000000
# 50%      38.000000   179.000000     2.00000   999.000000     0.000000
# 75%      47.000000   316.000000     3.00000   999.000000     0.000000
# max      89.000000  4918.000000    43.00000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   8237.000000     8237.000000    8237.000000  8237.000000  8237.000000
# mean       0.070147       93.577806     -40.545320     3.608206  5166.589790
# std        1.574685        0.582138       4.623626     1.735931    72.470977
# ...

# %% [markdown]
# histogram loading the libraries

# %%
import seaborn as sns

# %% [markdown]
# creating histogram

# %%
sns.histplot(x=bank['month'],bins=10,kde=True);

# %%
sns.histplot(x=bank['duration'],bins=10,kde=False,stat="probability",color='Pink');

# %% [markdown]
# filtering data

# %%
import pandas as  pd
bank=pd.read_csv('/content/gdrive/MyDrive/principles of data science lab/bank_marketing_test.csv')

# %% [markdown]
# boolean vector

# %%
bank['marital']=='single'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 8232    False
# 8233    False
# 8234    False
# 8235    False
# 8236    False
# Name: marital, Length: 8237, dtype: bool

# %%
bank[bank['marital']=="single"]
# Out:
#       age         job marital            education  default housing loan  \
# 2      25    services  single          high.school       no     yes   no
# 9      53      admin.  single  professional.course       no      no   no
# 11     25  technician  single    university.degree       no     yes   no
# 34     35     student  single    university.degree  unknown     yes   no
# 38     36  technician  single  professional.course       no      no   no
# ...   ...         ...     ...                  ...      ...     ...  ...
# 8209   21     student  single          high.school       no      no   no
# 8217   27     student  single          high.school       no      no  yes
# 8223   37  technician  single  professional.course       no     yes   no
# 8230   35      admin.  single  professional.course       no     yes   no
# 8231   35      admin.  single  professional.course       no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %%
singleEmployees=bank[bank['marital']=="Female"]
type(singleEmployees)
# Out:
# pandas.core.frame.DataFrame

# %%
singleEmployees['duration'].mean()
# Out:
# nan

# %%
round(singleEmployees['contact'].mean(),2)
# Out:
# nan

# %% [markdown]
# complex filtering creteria

# %%
(bank['marital']=='married')&(bank['job']==1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8232    False
# 8233    False
# 8234    False
# 8235    False
# 8236    False
# Length: 8237, dtype: bool

# %%
bank[(bank['marital']=='married')&(bank['job']==1)].shape
# Out:
# (0, 21)

# %% [markdown]
# filtering by a list

# %%
bank[bank['campaign']>=4]
# Out:
#       age            job   marital            education  default housing loan  \
# 55     40      housemaid    single  professional.course       no      no   no
# 57     35     management   married          high.school       no     yes   no
# 58     50  self-employed    single    university.degree       no      no  yes
# 59     49   entrepreneur   married          high.school       no     yes   no
# 62     41    blue-collar    single             basic.9y  unknown     yes   no
# ...   ...            ...       ...                  ...      ...     ...  ...
# 8159   50     management   married    university.degree       no      no   no
# 8163   58         admin.   married    university.degree       no      no   no
# 8165   34     technician   married  professional.course       no     yes   no
# 8208   62         admin.   married          high.school       no      no   no
# 8229   43         admin.  divorced    university.degree       no     yes   no
#
# ...

# %%
mgmt=[4,5,6]
bank[bank['campaign'].isin(mgmt)]
# Out:
#       age            job   marital            education  default housing loan  \
# 55     40      housemaid    single  professional.course       no      no   no
# 57     35     management   married          high.school       no     yes   no
# 58     50  self-employed    single    university.degree       no      no  yes
# 59     49   entrepreneur   married          high.school       no     yes   no
# 62     41    blue-collar    single             basic.9y  unknown     yes   no
# ...   ...            ...       ...                  ...      ...     ...  ...
# 8159   50     management   married    university.degree       no      no   no
# 8163   58         admin.   married    university.degree       no      no   no
# 8165   34     technician   married  professional.course       no     yes   no
# 8208   62         admin.   married          high.school       no      no   no
# 8229   43         admin.  divorced    university.degree       no     yes   no
#
# ...
