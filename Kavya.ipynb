# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pyspark
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.0-py2.py3-none-any.whl size=311317145 sha256=2510b77577cfe51819ff0e004009b323052e65b9af6a4be996ee4b1081873bbb
#   Stored in directory: /root/.cache/pip/wheels/9f/34/a4/159aa12d0a510d5ff7c8f0220abbea42e5d81ecf588c4fd884
# Successfully built pyspark
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
dft=pd.read_csv("/content/gdrive/MyDrive/fruitsdata.csv")
dft
# Out:
#     1000                Apple  4  133
# 0   1001              Apricot  5  175
# 1   1002              Avocado  5  182
# 2   1003               Banana  5  187
# 3   1004             Bilberry  5  160
# 4   1005           Blackberry  4  178
# ..   ...                  ... ..  ...
# 56  1057            Tangerine  4  119
# 57  1058               Tomato  6  167
# 58  1059           Ugli fruit  4  179
# 59  1060           Watermelon  6  149
# 60  1061  Ziziphus mauritiana  5  180
#
# [61 rows x 4 columns]

# %%
dft['Apple'][:5]
# Out:
# 0       Apricot
# 1       Avocado
# 2        Banana
# 3      Bilberry
# 4    Blackberry
# Name: Apple, dtype: object

# %%
dft.head(10)
# Out:
#    1000         Apple  4  133
# 0  1001       Apricot  5  175
# 1  1002       Avocado  5  182
# 2  1003        Banana  5  187
# 3  1004      Bilberry  5  160
# 4  1005    Blackberry  4  178
# 5  1006  Blackcurrant  5  102
# 6  1007     Blueberry  6  156
# 7  1008       Currant  5  194
# 8  1009        Cherry  5  182
# 9  1010     Cherimoya  3  169

# %%
dft.tail(10)
# Out:
#     1000                Apple  4  133
# 51  1052           Redcurrant  3  190
# 52  1053          Salal berry  3  137
# 53  1054              Satsuma  1  197
# 54  1055           Star fruit  4  142
# 55  1056           Strawberry  6  178
# 56  1057            Tangerine  4  119
# 57  1058               Tomato  6  167
# 58  1059           Ugli fruit  4  179
# 59  1060           Watermelon  6  149
# 60  1061  Ziziphus mauritiana  5  180

# %%
dft.dropna()
# Out:
#     1000                Apple  4  133
# 0   1001              Apricot  5  175
# 1   1002              Avocado  5  182
# 2   1003               Banana  5  187
# 3   1004             Bilberry  5  160
# 4   1005           Blackberry  4  178
# ..   ...                  ... ..  ...
# 56  1057            Tangerine  4  119
# 57  1058               Tomato  6  167
# 58  1059           Ugli fruit  4  179
# 59  1060           Watermelon  6  149
# 60  1061  Ziziphus mauritiana  5  180
#
# [61 rows x 4 columns]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=plt.imread("/content/gdrive/MyDrive/flower.jpg")
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
