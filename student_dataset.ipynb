# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from ast import increment_lineno
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
student=pd.read_csv('/content/gdrive/MyDrive/principles of data science lab/Marks.csv')
student
# Out:
#    Student ID       Name  English  Kannada  Hindi  Social  Science  Maths  \
# 0        I001    Deeksha       78       81   85.0     NaN       82   79.0
# 1        I002    Shravya       89       90   92.0    95.0       89   88.0
# 2        I003       Hani       56       65   53.0    60.0       58   50.0
# 3        I004      Divya       43       56   66.0    61.0       72   70.0
# 4        I005     Sahana       89       80   79.0    62.0       78   75.0
# 5        I006     Rashmi       32       45   44.0    63.0       58   61.0
# 6        I007      Nisha       90       80   88.0    66.0       71   64.0
# 7        I008     Varsha       85       90   92.0    76.0       82   77.0
# 8        I009  Deekshith       66       62   69.0    64.0       60   59.0
# 9        I010     Punith       78       87   82.0    81.0       77   73.0
# 10       I011     Brunda       34       60   55.0    45.0       51   50.0
# 11       I012   Shravana       28       56   42.0     NaN       62    NaN
# ...

# %%
student.head()
# Out:
#   Student ID     Name  English  Kannada  Hindi  Social  Science  Maths  Total  \
# 0       I001  Deeksha       78       81   85.0     NaN       82   79.0    405
# 1       I002  Shravya       89       90   92.0    95.0       89   88.0    543
# 2       I003     Hani       56       65   53.0    60.0       58   50.0    342
# 3       I004    Divya       43       56   66.0    61.0       72   70.0    368
# 4       I005   Sahana       89       80   79.0    62.0       78   75.0    463
#
#   Remarks
# 0    Pass
# 1    Pass
# 2    Pass
# 3    Pass
# 4    Pass

# %%
student.tail(3)
# Out:
#    Student ID     Name  English  Kannada  Hindi  Social  Science  Maths  \
# 17       I018  Amrutha       75       78    NaN    36.0       69   68.0
# 18       I005   Sahana       89       80   79.0    62.0       78   75.0
# 19       I020    Pooja       93       95   94.0    75.0       82   78.0
#
#     Total Remarks
# 17    326    Pass
# 18    463    Pass
# 19    517    Pass

# %%
student.describe(include='all')
# Out:
#        Student ID    Name    English    Kannada      Hindi     Social  \
# count          20      20  20.000000  20.000000  19.000000  18.000000
# unique         19      19        NaN        NaN        NaN        NaN
# top          I005  Sahana        NaN        NaN        NaN        NaN
# freq            2       2        NaN        NaN        NaN        NaN
# mean          NaN     NaN  67.750000  73.650000  70.684211  63.222222
# std           NaN     NaN  22.989414  15.211751  19.869163  17.942901
# min           NaN     NaN  28.000000  45.000000  27.000000  32.000000
# 25%           NaN     NaN  44.500000  60.750000  55.000000  60.250000
# 50%           NaN     NaN  76.000000  79.000000  75.000000  62.500000
# 75%           NaN     NaN  89.000000  82.500000  86.500000  75.000000
# max           NaN     NaN  99.000000  98.000000  95.000000  95.000000
#
#           Science      Maths       Total Remarks
# count   20.000000  19.000000   20.000000      20
# ...

# %%
student.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'English'}>,
#         <Axes: title={'center': 'Kannada'}>,
#         <Axes: title={'center': 'Hindi'}>],
#        [<Axes: title={'center': 'Social'}>,
#         <Axes: title={'center': 'Science'}>,
#         <Axes: title={'center': 'Maths'}>],
#        [<Axes: title={'center': 'Total'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.boxplot(x="Name",y="Total",data=student)
# Out:
# <Axes: xlabel='Name', ylabel='Total'>

# %%
sns.pairplot(student)

# %%
student.dropna()
# Out:
#    Student ID       Name  English  Kannada  Hindi  Social  Science  Maths  \
# 1        I002    Shravya       89       90   92.0    95.0       89   88.0
# 2        I003       Hani       56       65   53.0    60.0       58   50.0
# 3        I004      Divya       43       56   66.0    61.0       72   70.0
# 4        I005     Sahana       89       80   79.0    62.0       78   75.0
# 5        I006     Rashmi       32       45   44.0    63.0       58   61.0
# 6        I007      Nisha       90       80   88.0    66.0       71   64.0
# 7        I008     Varsha       85       90   92.0    76.0       82   77.0
# 8        I009  Deekshith       66       62   69.0    64.0       60   59.0
# 9        I010     Punith       78       87   82.0    81.0       77   73.0
# 10       I011     Brunda       34       60   55.0    45.0       51   50.0
# 12       I013      Punya       77       81   75.0    62.0       85   78.0
# 13       I014     Srujan       42       54   27.0    32.0       45   39.0
# ...

# %%
student=student.rename(columns={"Name":"Student Name","Maths":"Mathematics"})

# %%
student.head(5)
# Out:
#   Student ID Student Name  English  Kannada  Hindi  Social  Science  \
# 0       I001      Deeksha       78       81   85.0     NaN       82
# 1       I002      Shravya       89       90   92.0    95.0       89
# 2       I003         Hani       56       65   53.0    60.0       58
# 3       I004        Divya       43       56   66.0    61.0       72
# 4       I005       Sahana       89       80   79.0    62.0       78
#
#    Mathematics  Total Remarks
# 0         79.0    405    Pass
# 1         88.0    543    Pass
# 2         50.0    342    Pass
# 3         70.0    368    Pass
# 4         75.0    463    Pass

# %%
duplicate_rows_student=student[student.duplicated()]

# %%
print("Number of duplicate rows:",duplicate_rows_student.shape)
# Out:
# Number of duplicate rows: (1, 10)

# %%
student.count()
# Out:
# Student ID      20
# Student Name    20
# English         20
# Kannada         20
# Hindi           19
# Social          18
# Science         20
# Mathematics     19
# Total           20
# Remarks         20
# dtype: int64

# %%
student=student.drop_duplicates()
student.head(20)
# Out:
#    Student ID Student Name  English  Kannada  Hindi  Social  Science  \
# 0        I001      Deeksha       78       81   85.0     NaN       82
# 1        I002      Shravya       89       90   92.0    95.0       89
# 2        I003         Hani       56       65   53.0    60.0       58
# 3        I004        Divya       43       56   66.0    61.0       72
# 4        I005       Sahana       89       80   79.0    62.0       78
# 5        I006       Rashmi       32       45   44.0    63.0       58
# 6        I007        Nisha       90       80   88.0    66.0       71
# 7        I008       Varsha       85       90   92.0    76.0       82
# 8        I009    Deekshith       66       62   69.0    64.0       60
# 9        I010       Punith       78       87   82.0    81.0       77
# 10       I011       Brunda       34       60   55.0    45.0       51
# 11       I012     Shravana       28       56   42.0     NaN       62
# 12       I013        Punya       77       81   75.0    62.0       85
# ...

# %%
print(student.isnull().sum())
# Out:
# Student ID      0
# Student Name    0
# English         0
# Kannada         0
# Hindi           1
# Social          2
# Science         0
# Mathematics     1
# Total           0
# Remarks         0
# dtype: int64

# %%
student=student.dropna()
student
# Out:
#    Student ID Student Name  English  Kannada  Hindi  Social  Science  \
# 1        I002      Shravya       89       90   92.0    95.0       89
# 2        I003         Hani       56       65   53.0    60.0       58
# 3        I004        Divya       43       56   66.0    61.0       72
# 4        I005       Sahana       89       80   79.0    62.0       78
# 5        I006       Rashmi       32       45   44.0    63.0       58
# 6        I007        Nisha       90       80   88.0    66.0       71
# 7        I008       Varsha       85       90   92.0    76.0       82
# 8        I009    Deekshith       66       62   69.0    64.0       60
# 9        I010       Punith       78       87   82.0    81.0       77
# 10       I011       Brunda       34       60   55.0    45.0       51
# 12       I013        Punya       77       81   75.0    62.0       85
# 13       I014       Srujan       42       54   27.0    32.0       45
# 14       I015      Sharath       99       98   95.0    90.0       91
# ...

# %%
student.count()
# Out:
# Student ID      16
# Student Name    16
# English         16
# Kannada         16
# Hindi           16
# Social          16
# Science         16
# Mathematics     16
# Total           16
# Remarks         16
# dtype: int64

# %%
student.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of    Student ID Student Name  English  Kannada  Hindi  Social  Science  \
# 1        I002      Shravya       89       90   92.0    95.0       89
# 2        I003         Hani       56       65   53.0    60.0       58
# 3        I004        Divya       43       56   66.0    61.0       72
# 4        I005       Sahana       89       80   79.0    62.0       78
# 5        I006       Rashmi       32       45   44.0    63.0       58
# 6        I007        Nisha       90       80   88.0    66.0       71
# 7        I008       Varsha       85       90   92.0    76.0       82
# 8        I009    Deekshith       66       62   69.0    64.0       60
# 9        I010       Punith       78       87   82.0    81.0       77
# 10       I011       Brunda       34       60   55.0    45.0       51
# 12       I013        Punya       77       81   75.0    62.0       85
# 13       I014       Srujan       42       54   27.0    32.0       45
# ...

# %%
print(np.sum(student,axis=1))
# Out:
# 1     1086.0
# 2      684.0
# 3      736.0
# 4      926.0
# 5      606.0
# 6      918.0
# 7     1004.0
# 8      760.0
# 9      956.0
# 10     590.0
# 12     916.0
# 13     478.0
# 14    1122.0
# 15     554.0
# 16     886.0
# 19    1034.0
# dtype: float64
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:84: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
print(np.std(student))
# Out:
# English        22.153495
# Kannada        15.755455
# Hindi          19.376109
# Social         17.102631
# Science        15.188272
# Mathematics    14.915255
# Total          97.542619
# dtype: float64
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3613: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
print(np.mean(student))
# Out:
# English         67.8125
# Kannada         73.6250
# Hindi           71.0625
# Social          65.0000
# Science         70.0625
# Mathematics     66.6875
# Total          414.2500
# dtype: float64
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
print(np.var(student))
# Out:
# English         490.777344
# Kannada         248.234375
# Hindi           375.433594
# Social          292.500000
# Science         230.683594
# Mathematics     222.464844
# Total          9514.562500
# dtype: float64
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3755: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
